# %% [markdown]
# # Résultats de génération de musique
# Ce fichier présente nos résultats de musiques générées avec différents modèles.
#
# Sommaire:
# * Aléatoire
# * VAE
# * LSTM
# * GAN

# %%
import music21 as m21

def listenTo(path):
    mf = m21.midi.MidiFile()
    mf.open(path)
    mf.read()
    mf.close()
    song = m21.midi.translate.midiFileToStream(mf)
    song.show()
    song.show("midi")

# %% [markdown]
# # Aléatoire

# %%
listenTo("ALEA/random.mid")
# Out:
#         <div id="midiPlayerDiv15739"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv15739_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv15739");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv15739_play, 2000);
#         } else {
#             midiPlayerDiv15739_play();
#         }
#         </script>

# %%
listenTo("ALEA/random_with_chords.mid")
# Out:
#         <div id="midiPlayerDiv16116"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv16116_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv16116");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv16116_play, 2000);
#         } else {
#             midiPlayerDiv16116_play();
#         }
#         </script>

# %% [markdown]
# # VAE

# %% [markdown]
# Première version du VAE (pas super)

# %%
listenTo("AUTO/vae1_0407.mid")
# Out:
#         <div id="midiPlayerDiv16673"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv16673_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv16673");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv16673_play, 2000);
#         } else {
#             midiPlayerDiv16673_play();
#         }
#         </script>

# %% [markdown]
# VAE deuxième version. \
# Version originale (provenant du dataset) transposée

# %%
listenTo("AUTO/VAE2/han0030_transposed.mid")
# Out:
#         <div id="midiPlayerDiv18868"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv18868_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv18868");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv18868_play, 2000);
#         } else {
#             midiPlayerDiv18868_play();
#         }
#         </script>

# %% [markdown]
# Version reconstruite après passage dans le VAE

# %%
listenTo("AUTO/VAE2/han0030_reconstructed.mid")
# Out:
#         <div id="midiPlayerDiv20073"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv20073_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv20073");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv20073_play, 2000);
#         } else {
#             midiPlayerDiv20073_play();
#         }
#         </script>

# %% [markdown]
# ## LSTM

# %% [markdown]
# ### Dataset han

# %% [markdown]
# Deux mélodies générées avec un LSTM entraîné sur 10 époques sur le dataset **han**. Une note de départ : sol

# %%
listenTo("RNN-LSTM/han/0604_163404_4.mid")
# Out:
#         <div id="midiPlayerDiv6872"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv6872_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv6872");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv6872_play, 2000);
#         } else {
#             midiPlayerDiv6872_play();
#         }
#         </script>

# %%
listenTo("RNN-LSTM/han/0604_163404_1.mid")
# Out:
#         <div id="midiPlayerDiv7412"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv7412_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv7412");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv7412_play, 2000);
#         } else {
#             midiPlayerDiv7412_play();
#         }
#         </script>

# %% [markdown]
# ### Dataset deutsch

# %% [markdown]
# Trois mélodies générées avec un LSTM entraîné sur 10 époques sur le dataset **deutsch**. Une note de départ : sol

# %%
listenTo("RNN-LSTM/deutsch/0604_173326_4.mid")
# Out:
#         <div id="midiPlayerDiv3404"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv3404_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv3404");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv3404_play, 2000);
#         } else {
#             midiPlayerDiv3404_play();
#         }
#         </script>

# %%
listenTo("RNN-LSTM/deutsch/0604_154023_4.mid")
# Out:
#         <div id="midiPlayerDiv6224"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv6224_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv6224");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv6224_play, 2000);
#         } else {
#             midiPlayerDiv6224_play();
#         }
#         </script>

# %%
listenTo("RNN-LSTM/deutsch/0604_173326_3.mid")
# Out:
#         <div id="midiPlayerDiv5073"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv5073_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv5073");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv5073_play, 2000);
#         } else {
#             midiPlayerDiv5073_play();
#         }
#         </script>

# %% [markdown]
# Deux mélodies générées avec un LSTM entraîné sur **25** époques sur le dataset **deutsch**. Une note de départ : sol

# %%
listenTo("RNN-LSTM/deutsch/2604_161347_3.mid")
# Out:
#         <div id="midiPlayerDiv14729"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv14729_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv14729");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv14729_play, 2000);
#         } else {
#             midiPlayerDiv14729_play();
#         }
#         </script>

# %%
listenTo("RNN-LSTM/deutsch/2604_161347_5.mid")
# Out:
#         <div id="midiPlayerDiv15374"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv15374_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv15374");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv15374_play, 2000);
#         } else {
#             midiPlayerDiv15374_play();
#         }
#         </script>

# %% [markdown]
# ### Compléter le début de "ah vous dirais-je maman"

# %% [markdown]
# Mélodie originale

# %%
listenTo("RNN-LSTM/ahVousDiraisJeMaman/original.midi")
# Out:
#         <div id="midiPlayerDiv21975"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv21975_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv21975");
#                 mp.base64Load("...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv21975_play, 2000);
#         } else {
#             midiPlayerDiv21975_play();
#         }
#         </script>

# %% [markdown]
# Mélodie générée avec le dataset han (10 époques)

# %%
listenTo("RNN-LSTM/ahVousDiraisJeMaman/han.midi")
# Out:
#         <div id="midiPlayerDiv21514"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv21514_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv21514");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv21514_play, 2000);
#         } else {
#             midiPlayerDiv21514_play();
#         }
#         </script>

# %% [markdown]
# Mélodie générée avec le dataset deutsch (10 époques)

# %%
listenTo("RNN-LSTM/ahVousDiraisJeMaman/deutsch.midi")
# Out:
#         <div id="midiPlayerDiv23720"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv23720_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv23720");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv23720_play, 2000);
#         } else {
#             midiPlayerDiv23720_play();
#         }
#         </script>

# %% [markdown]
# Mélodies générées avec le dataset deutsch (25 époques)

# %%
listenTo("RNN-LSTM/ahVousDiraisJeMaman/deutsch-25.midi")
# Out:
#         <div id="midiPlayerDiv24771"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv24771_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv24771");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv24771_play, 2000);
#         } else {
#             midiPlayerDiv24771_play();
#         }
#         </script>

# %% [markdown]
# # GAN

# %% [markdown]
# Gan simple avec dataset han

# %%
listenTo("GAN/gan_simple.mid")
# Out:
#         <div id="midiPlayerDiv1647"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv1647_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv1647");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv1647_play, 2000);
#         } else {
#             midiPlayerDiv1647_play();
#         }
#         </script>

# %% [markdown]
# Gan simple avec dataset deutsch

# %%
listenTo("GAN/gan_simple_deutsch.mid")
# Out:
#         <div id="midiPlayerDiv3285"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv3285_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv3285");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv3285_play, 2000);
#         } else {
#             midiPlayerDiv3285_play();
#         }
#         </script>

# %% [markdown]
# Gan convolutif avec dataset han

# %%
listenTo("GAN/gan_conv.mid")
# Out:
#         <div id="midiPlayerDiv25941"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv25941_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv25941");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv25941_play, 2000);
#         } else {
#             midiPlayerDiv25941_play();
#         }
#         </script>

# %% [markdown]
# Gan complexe avec dataset Deutsch

# %%
listenTo("GAN/gan_cpx_deutsch2.mid")
# Out:
#         <div id="midiPlayerDiv2535"></div>
#         <link rel="stylesheet" href="https://cuthbertLab.github.io/music21j/css/m21.css">
#
#         <script
#         src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js"
#         ></script>
#
#         <script>
#         function midiPlayerDiv2535_play() {
#             const rq = require.config({
#                 paths: {
#                     'music21': 'https://cuthbertLab.github.io/music21j/releases/music21.debug',
#                 }
#             });
#             rq(['music21'], function(music21) {
#                 mp = new music21.miditools.MidiPlayer();
#                 mp.addPlayer("#midiPlayerDiv2535");
#                 mp.base64Load("data:audio/midi;base64,...");
#             });
#         }
#         if (typeof require === 'undefined') {
#             setTimeout(midiPlayerDiv2535_play, 2000);
#         } else {
#             midiPlayerDiv2535_play();
#         }
#         </script>
